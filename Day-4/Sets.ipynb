# %% [markdown]
# # Sets

# %% [markdown]
# A Set is an unordered collection data type that is iterable, mutable, and has no duplicate elements, Python's set class represents the mathematical

# %%
set_var = {"Absman", "Jaitman", "monkeyman"}
print(set_var)
type(set_var)
# Out:
# {'Jaitman', 'Absman', 'monkeyman'}
# set

# %%
#inbuilt func

set_var.add("jakoman")
print(set_var)
# Out:
# {'Jaitman', 'Absman', 'jakoman', 'monkeyman'}

# %%
#intersection (gets the common values present in multiple sets)
set1= {"Absman", "Jaitman", "Monkeyman"}
set2= {"Liger", "Jaitman","Monkeyman","Jakoman"}

# %%
set2.intersection_update(set1)
set2
# Out:
# {'Jaitman', 'Monkeyman'}

# %%
set1, set2
# Out:
# ({'Absman', 'Jaitman', 'Monkeyman'},
#  {'Jaitman', 'Jakoman', 'Liger', 'Monkeyman'})

# %%
#Difference
set2.difference_update(set1)
set2
# Out:
# {'Jakoman', 'Liger'}
