# %% [markdown]
# # Tuples

# %% [markdown]
# Duplicates are allowed, an ordered, immutable collection of items

# %%
my_tuple = tuple(["kane", "king", "tiger"])

# %%
type(my_tuple)
# Out:
# tuple

# %%
my_tuple.count('kane')
# Out:
# 1

# %%
my_tuple.index('tiger')
# Out:
# 2
